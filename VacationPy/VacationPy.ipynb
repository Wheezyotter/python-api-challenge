# %% [markdown]
# # VacationPy
# ---

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
city_data = pd.read_csv("Data/cities.csv")

city_data.head()
# Out:
#    City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0         faya  18.3851   42.4509     22.06        35          21
# 1        1      farsund  58.0948    6.8047     13.30       100           0
# 2        2  new norfolk -42.7826  147.0587     11.72        58          12
# 3        3    jamestown  42.0970  -79.2353      5.77        77         100
# 4        4      lanzhou  36.0564  103.7922     14.53        48          59
#
#    Wind Speed Country        Date
# 0        2.60      SA  1666108228
# 1        7.65      NO  1666108228
# 2        1.34      AU  1666108230
# 3        9.77      US  1666107934
# 4        1.20      CN  1666108230

# %%
# %%capture --no-display

world_city_map = city_data.hvplot.points(
    "Lng",
    "Lat",
    frame_width = 700,
    frame_height = 500, 
    geo = True,
    tiles = "OSM",
    size = "Humidity",
    color = "City",
    alpha = .5,
    hover_alpha = 1,
    legend = False,
    title = "World Cities",
    xlabel = "Longitude",
    ylabel = "Latitude"
)

world_city_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %%
ideal_temp_filter = (city_data["Max Temp"] >= 18) & (city_data["Max Temp"] <= 26)
ideal_humid_filter = (city_data["Humidity"] <= 60)
ideal_cloud_filter = (city_data["Cloudiness"] <= 50)
ideal_wind_filter = (city_data["Wind Speed"] >= 1) & (city_data["Wind Speed"] <= 5)

ideal_city_data = city_data.loc[ideal_temp_filter & 
                                ideal_humid_filter & 
                                ideal_cloud_filter & 
                                ideal_wind_filter]

ideal_city_data
# Out:
#      City_ID            City      Lat       Lng  Max Temp  Humidity  \
# 0          0            faya  18.3851   42.4509     22.06        35
# 63        63           banda  25.4833   80.3333     24.62        52
# 152      152         kahului  20.8947 -156.4700     23.80        60
# 218      218    sao teotonio  37.5128   -8.7071     22.45        60
# 296      296            jalu  29.0331   21.5482     22.33        37
# 305      305         kingman  35.1894 -114.0530     20.07        49
# 317      317         salalah  17.0151   54.0924     25.49        59
# 363      363          narwar  25.6500   77.9000     22.35        55
# 391      391  saint-francois  46.4154    3.9054     23.69        57
# 413      413         kalemie  -5.9475   29.1947     25.52        60
#
#      Cloudiness  Wind Speed Country        Date
# 0            21        2.60      SA  1666108228
# 63            0        2.68      IN  1666108268
# 152           0        3.09      US  1666108246
# ...

# %%
hotel_df = pd.DataFrame({
    "City" : ideal_city_data["City"],
    "Country" : ideal_city_data["Country"],
    "Lat" : ideal_city_data["Lat"],
    "Long" : ideal_city_data["Lng"],
    "Humidity" : ideal_city_data["Humidity"],
    "Hotel Name" : ""
})

hotel_df
# Out:
#                City Country      Lat      Long  Humidity Hotel Name
# 0              faya      SA  18.3851   42.4509        35
# 63            banda      IN  25.4833   80.3333        52
# 152         kahului      US  20.8947 -156.4700        60
# 218    sao teotonio      PT  37.5128   -8.7071        60
# 296            jalu      LY  29.0331   21.5482        37
# 305         kingman      US  35.1894 -114.0530        49
# 317         salalah      OM  17.0151   54.0924        59
# 363          narwar      IN  25.6500   77.9000        55
# 391  saint-francois      FR  46.4154    3.9054        57
# 413         kalemie      CD  -5.9475   29.1947        60

# %% [markdown]
# ##### Code below from Starter_Code unless other wise indicated

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    # YOUR CODE HERE
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    # YOUR CODE HERE
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = # YOUR CODE HERE
    params["bias"] = # YOUR CODE HERE
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = # YOUR CODE HERE
    
    # Convert the API response to JSON format
    name_address = # YOUR CODE HERE
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
